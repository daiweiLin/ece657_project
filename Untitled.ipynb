# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./dataset/creditcard.csv')
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.to_csv('./dataset/creditcard.data', header=False)

# %%
import pdb
from C45_master.c45.c45 import C45

c1 = C45("./dataset/creditcard.data", "./dataset/creditcard.names")
c1.fetchData()
c1.preprocessData()
c1.generateTree()
c1.printTree()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e83b85b40aea> in <module>
#       5 c1.fetchData()
#       6 c1.preprocessData()
# ----> 7 c1.generateTree()
#       8 c1.printTree()
#
# F:\Winter2019\ECE657A\Project\ece657_project\C45_master\c45\c45.py in generateTree(self)
#      68
#      69         def generateTree(self):
# ---> 70                 self.tree = self.recursiveGenerateTree(self.data, self.attributes)
#      71
#      72         def recursiveGenerateTree(self, curData, curAttributes):
#
# F:\Winter2019\ECE657A\Project\ece657_project\C45_master\c45\c45.py in recursiveGenerateTree(self, curData, curAttributes)
#      84                         return Node(True, majClass, None)
#      85                 else:
# ---> 86                         (best,best_threshold,splitted) = self.splitAttribute(curData, curAttributes)
# ...

# %%
# %run "Python-DM-Classification-04-C4.5"
df = pd.read_csv('./dataset/creditcard.csv', sep = ',')

# %%
X = df.iloc[:800, :-1]
y = df.iloc[:800, -1]

# %%
X.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V20       V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...  0.251412 -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ... -0.069083 -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...  0.524980  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ... -0.208038 -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...  0.408542 -0.009431  0.798278 -0.137458  0.141267
#
# ...

# %%
np.sum(y==1)
# Out:
# 2

# %%
import time
start_t = time.time()
dt_model = dt_c45(Xdata = X, ydata = y, cat_missing = "missing", num_missing = "mean", pre_pruning = "impur", chi_lim = 0.1, min_lim = 5)
print("total seconds:{}".format(time.time()-start_t))
# Calling Prediction
test =  df.iloc[0:2, :]
prediction_dt_c45(dt_model, test)
