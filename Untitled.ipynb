# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
spam_data = pd.read_csv("./dataset/spambase.data", header=None)
# add column names to spam_data 
spam_names = pd.read_csv('./dataset/spambase.names',sep=':',header=None)
names = spam_names[0].tolist()
names.append("Class")
print(len(names))

spam_data.columns = names
spam_data.head()
# Out:
# 58
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...    char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...           0.00        0.000
# 1             0.00            0.94  ...           0.00        0.132
# 2             0.64            0.25  ...           0.01        0.143
# 3             0.31            0.63  ...           0.00        0.137
# 4             0.31            0.63  ...           0.00        0.135
#
#    char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# 0          0.0        0.778        0.000        0.000
# 1          0.0        0.372        0.180        0.048
# 2          0.0        0.276        0.184        0.010
# 3          0.0        0.137        0.000        0.000
# 4          0.0        0.135        0.000        0.000
#
#    capital_run_length_average  capital_run_length_longest  \
# 0                       3.756                          61
# 1                       5.114                         101
# 2                       9.821                         485
# 3                       3.537                          40
# 4                       3.537                          40
#
#    capital_run_length_total  Class
# 0                       278      1
# 1                      1028      1
# 2                      2259      1
# 3                       191      1
# 4                       191      1
#
# [5 rows x 58 columns]

# %%
spam_data_sampled = spam_data.sample(frac=0.1)
print(spam_data_sampled.shape)
# Out:
# (460, 58)

# %%
import random
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score

parent_node = None
# the node class that will make up the tree
class decisionTreeNode():
    def __init__(self, is_leaf_node, classification, attribute_split_value, parent, left_child, right_child, height):

        self.classification = None
        self.attribute_split = None
        self.attribute_split_value = None
        self.parent = parent
        self.left_child = None
        self.right_child = None
        self.height = None
        self.is_leaf_node = True



#Split the data based on the feature and a value to data above and data below
def split_data(data, split_column, split_value):
    
    split_column_values = data[:, split_column]

    data_below = data[split_column_values <= split_value]
    data_above = data[split_column_values >  split_value]
    
    return data_below, data_above

#Get all the boundary values for each features (Key is feature and values are the splits)
def get_potential_splits(data):
    
    potential_splits = {}
    _, n_columns = data.shape
    for column_index in range(n_columns - 1):        # excluding the last column which is the label
        potential_splits[column_index] = []
        values = data[:, column_index]
        unique_values = np.unique(values)

        for index in range(len(unique_values)):
            if index != 0:
                current_value = unique_values[index]
                previous_value = unique_values[index - 1]
                potential_split = (current_value + previous_value) / 2
                
                potential_splits[column_index].append(potential_split)
        if (unique_values.shape[0] == 1):
            potential_split = unique_values[index]
            
            potential_splits[column_index].append(potential_split)

    
    return potential_splits

#Calculates Entropy of the data given
def calculate_entropy(data):
    
    label_column = data[:, -1]
    _, counts = np.unique(label_column, return_counts=True)

    probabilities = counts / counts.sum()
    entropy = sum(probabilities * -np.log2(probabilities))
     
    return entropy

#Calculates the entropy of data below and data above
def calculate_overall_entropy(data_below, data_above):
    
    n = len(data_below) + len(data_above)
    p_data_below = len(data_below) / n
    p_data_above = len(data_above) / n

    overall_entropy =  (p_data_below * calculate_entropy(data_below) 
                      + p_data_above * calculate_entropy(data_above))
    
    return overall_entropy

#Check if all data is of same class
def check_purity(data):
    
    label_column = data[:, -1]
    unique_classes = np.unique(label_column)

    if len(unique_classes) == 1:
        return True
    else:
        return False

#Classify data based on majority
def classify_data(data):
    
    label_column = data[:, -1]
    unique_classes, counts_unique_classes = np.unique(label_column, return_counts=True)

    index = counts_unique_classes.argmax()
    classification = unique_classes[index]
    
    return classification

#Gives the best feature and its split value after checking all features based on gain ratio
def determine_best_split(data, potential_splits):
    
    entropy_label = calculate_entropy(data)   
    overall_gain = -1.0
    for column_index in potential_splits:
        for value in potential_splits[column_index]:
            data_below, data_above = split_data(data, split_column=column_index, split_value=value)
            current_overall_entropy = calculate_overall_entropy(data_below, data_above)
            current_information_gain = entropy_label - current_overall_entropy
            current_splitting_info = splitting_information(data_below,data_above)
            if current_splitting_info == 0:
                current_gain_ratio = 0
            else:
                current_gain_ratio = float(current_information_gain / current_splitting_info)

            if current_gain_ratio >= overall_gain:
                overall_gain = current_gain_ratio
                best_split_column = column_index
                best_split_value = value
    
    return best_split_column, best_split_value

#Calculates the splitting Info of data above and below for that boundary value
def splitting_information(data_below,data_above):
    n = len(data_below) + len(data_above)
    p_data_below = len(data_below)/ n
    p_data_above = len(data_above) / n

    if p_data_below == 0:
        splitting_info = p_data_above * np.log2(p_data_above)
    elif p_data_above == 0:
        splitting_info = p_data_below * np.log2(p_data_below)
    else:
        splitting_info = -p_data_below * np.log2(p_data_below) -p_data_above * np.log2(p_data_above) 
    
    return splitting_info

def decision_tree_algorithm(df, parent_node,counter=0, min_samples=3):
    node = decisionTreeNode(True, None, None, parent_node, None, None, 0)
    # data preparations
    if counter == 0:
        global COLUMN_HEADERS
        COLUMN_HEADERS = df.columns
        data = df.values
    else:
        data = df           
    
    
    # base cases
    if (check_purity(data)) or (len(data) < min_samples):
        classification = classify_data(data)
        node.is_leaf_node = True
        node.classification = classification
        return node

    
    # recursive part
    else:    
        counter += 1

        # helper functions 
        potential_splits = get_potential_splits(data)
        split_column, split_value = determine_best_split(data, potential_splits)
        data_below, data_above = split_data(data, split_column, split_value)
        node.is_leaf_node = False
        # instantiate sub-tree
        feature_name = COLUMN_HEADERS[split_column]
        
        question = "{} <= {}".format(feature_name, split_value)


       
        if (parent_node == None):
            node.height = 0
        else:
            node.parent = parent_node
            node.height = node.parent.height + 1


        node.attribute_split = feature_name
        node.attribute_split_value = split_value

        # find answers (recursion)
        node.left_child = decision_tree_algorithm(data_below,node, counter, min_samples)
        node.right_child = decision_tree_algorithm(data_above,node, counter, min_samples)
        

        return node

def get_paths(root, path, pathlen,all_paths,val):
    if (root==None):
        return
    
    if root.is_leaf_node == True: 
        path.append(root.classification) 
    else:
        path.append('row[\'' + root.attribute_split + '\']' + val + str(root.attribute_split_value))
        
    pathlen= pathlen+1
    if (root.left_child == None and root.right_child == None): # If leaf, append current path
        add = path[:]
        all_paths.append(add)
        path.pop()
        root = root.parent
    else:
        get_paths(root.left_child, path, pathlen,all_paths,' <= ')
        path[pathlen-1]= 'row[\'' + root.attribute_split + '\']' +' > ' + str(root.attribute_split_value)
        get_paths(root.right_child, path,pathlen,all_paths,' <= ')
        path.pop()

    return all_paths

def classify_test_data(root,data):
    predictions = []
    tree = root 
    data = data.iloc[:, :-1]
    for index, sample in data.iterrows():
        root = tree
        while(tree.is_leaf_node!=True):
            if (sample.loc[tree.attribute_split] <= tree.attribute_split_value):
                tree = tree.left_child
            else:
                tree = tree.right_child
        predictions.append(tree.classification)
        tree = root

    return predictions

def calc_accuracy_rule(rule,test):
    wrong = 0
#Check how many classified correctly
    for index, row in test.iterrows():
        s=0
        while(s<len(rule)-1):
            if (eval(rule[s])== False):
                wrong += 1
                break
            s=s+1
    #Initial Accuracy of one Rule before pruning
    accuracy = (test.shape[0]-wrong) / test.shape[0]
    return accuracy


def recursive_len(item):
    if type(item) == list:
        return sum(recursive_len(subitem) for subitem in item)
    else:
        return 1
    
def prune(all_rules,val_data):
    acc_rlist = []
    maping = []
    rulenos = []
    #What are the labels in my val data
    ctoprune = val_data['Class'].unique()
#     Loop at all rules one by one
    size_of_rules = recursive_len(all_rules)
    print("before pruning:",size_of_rules)
    for i in range(len(all_rules)):
        init_accuracy = 0
        #Loop only on the rules applicable to my valset
        if all_rules[i][-1] in ctoprune:
                #Get the label of the Rule
                label = all_rules[i][-1]
                #Get all samples for that label
                test = val_data[val_data['Class']==label]
                #Check Initial Accuracy of the rule
                init_accuracy = calc_accuracy_rule(all_rules[i],test)
                print("initial_accuracy: {}".format(init_accuracy))
                
                pruned_accuracy = -1
                while (init_accuracy!=pruned_accuracy):
                # if (init_accuracy!=pruned_accuracy):
                    for x in range(len(all_rules[i])-1):
                        temp = all_rules[i][:]
                        del temp[x]
                        accuracy = calc_accuracy_rule(temp,test)
                        if accuracy > init_accuracy:
                            print("Better accuracy:{}".format(accuracy))
                            delx = x
                            init_accuracy = accuracy
                        
                    # Ensure variable is defined
                    try:
                        delx
                    except NameError:
                        delx = None

                    if delx is not None:
                        del all_rules[i][delx]
                        del delx
                        # pruned_accuracy = init_accuracy
                        if (len(all_rules[i])== 2):
                            pruned_accuracy = init_accuracy
                    else:
                        pruned_accuracy = init_accuracy
        else:
            pruned_accuracy = init_accuracy
        acc_rlist.append(pruned_accuracy)
        rulenos.append(i)
    maping.append(acc_rlist)
    maping.append(rulenos)
    size_of_rules = recursive_len(all_rules)
    print("after pruning:",size_of_rules)
    maping= np.array(maping)
    maping = pd.DataFrame(maping.T)
    maping = maping.sort_values(0,ascending=False)
    maping = pd.DataFrame(maping)
    return all_rules,maping
                
def predict_prunedtree(all_rules,test_data,maping):
    answer = []
    unclassified = 0
    for index, row in test_data.iterrows():
        for indo,valus in maping.iterrows():
            rule = all_rules[int(valus[1])]
            s=0
            count = 0
            while(s<len(rule)-1):
                if (eval(rule[s])== True):
                    count = count + 1
                s = s+1
            if (count == len(rule)-1):
                prediction = rule[-1]
                break
        try:
            prediction
        except NameError:
            prediction = None
        if prediction is not None:
            answer.append(prediction)
            del prediction
        else:
            unclassified = unclassified + 1
#     print('Unclassified Sample',unclassified)
    return answer

def predict_preprunedtree(all_rules,test_data):
    answer = []
    unclassified = 0
    for index, row in test_data.iterrows():
        # prediction = row[-1]
        for rule in all_rules:
            s=0
            count = 0
            while(s<len(rule)-1):
                if (eval(rule[s])== True):
                    count = count + 1
                s = s+1
            if (count == len(rule)-1):
                prediction = rule[-1]
                break
        try:
            prediction
        except NameError:
            prediction = None
        if prediction is not None:
            answer.append(prediction)
            del prediction
        else:
            unclassified = unclassified + 1
#     print('Unclassified Sample',unclassified)
    return answer

def add_noise2(num,data):

    siz_d = data.shape[0]
    indx = int((num * siz_d)/100)
    for x in range(indx):
        pick = random.randint(0,int(siz_d/2))
        label = data.iloc[pick:,-1].values[0]
        if label > 0:
            data.iloc[pick:,-1] = data.iloc[pick:,-1] - 1
        else:
            data.iloc[pick:,-1] = data.iloc[pick:,-1] + 1
    return data

def add_noise1(num,data):
    siz_d = data.shape[0]
    indx = int((num * siz_d)/100)
    count = 0
    for x in range(indx):
        count = count+1
        pick = random.randint(0,siz_d)
        label = data.iloc[pick:,-1].values[0]
        if label > 0:
            label = label + 1
        else:
            label = label - 1
        last = data.shape[0]  
        data = data.append(data.iloc[pick,:])
        data.iloc[last,-1] = label
    return data

noise1_5 = []
noise1_10 = []
noise1_15 = []
noise2_5 = []
noise2_10 = []
noise2_15 = []

if __name__ == "__main__":
    meanacc= []
    meanf1_score= []
    meanrecall_score= []
    maping = []
    mean_bprun = []
    rkf = RepeatedKFold(n_splits=5, n_repeats=2, random_state=2652124)
    for train_index, test_index in rkf.split(spam_data_sampled):
        parent_node = None
        test_data = spam_data_sampled.iloc[test_index]
        train_data,val_data= train_test_split(spam_data_sampled.iloc[train_index], test_size=0.2)
        
        tree = decision_tree_algorithm(train_data,parent_node)
        all_rules = get_paths(tree,[],0,[],' <= ')


        
# #         #Validation
# #         y_true= val_data.iloc[:,-1].values
# #         y_pred = classify_test_data(tree,val_data)
# #         accuracy = accuracy_score(y_true, y_pred)
# #         print('Pre-Pruning Accuracy of Val data With Just Tree',accuracy)
        
#         # # Pre-Pruning Accuracy of Test Data With Tree
#         # y_true= test_data.iloc[:,-1].values
#         # y_pred = classify_test_data(tree,test_data)
#         # accuracy = accuracy_score(y_true, y_pred)
#         # print('Pre-Pruning Accuracy of Test data With Just Tree',accuracy)
        accuracy = []
        #Pre-Pruning Accuracy of Test Data With Rules
        y_true= test_data.iloc[:,-1].values
        answer = predict_preprunedtree(all_rules,test_data)
        accuracy = accuracy_score(y_true, answer)
        f1_sc = f1_score(y_true, answer)
        recall_sc = recall_score(y_true, answer)
        print('Accuracy of Test Data With Rules',accuracy)
        print('f1_score of Test Data With Rules',f1_sc)
        print('recall_score of Test Data With Rules',recall_sc)
        #print('Number of Rules before pruning',len(all_rules))
        mean_bprun.append(accuracy)
        #Post Pruning Accuracy with Rules
        all_rules,maping = prune(all_rules,val_data)
        print('Number of Rules after pruning',len(all_rules))
        answer = predict_prunedtree(all_rules,test_data,maping)
        # y_true= test_data.iloc[:,-1].values
        accuracy = accuracy_score(y_true, answer)
       # print('Post-Pruned Accuracy Without Noise',accuracy)
        meanacc.append(accuracy)
        meanf1_score.append(f1_sc)
        meanrecall_score.append(recall_sc)

        
    print('Mean Accuracy So Far on Test:',sum(meanacc) / len(meanacc))
    print('The Mean Accuracy of Classifier',sum(mean_bprun) / len(mean_bprun))
    print('The Mean Variance of Classifier',np.var(np.array(mean_bprun)))
    print('Mean f1_score So Far on Test:',sum(meanf1_score) / len(meanf1_score))
    print('Mean recall_score So Far on Test:',sum(meanrecall_score) / len(meanrecall_score))
# Out:
# Accuracy of Test Data With Rules 0.782608695652174
# f1_score of Test Data With Rules 0.7619047619047619
# recall_score of Test Data With Rules 0.8205128205128205
# before pruning: 410
# initial_accuracy: 0.1702127659574468
# Better accuracy:0.3404255319148936
# Better accuracy:0.3617021276595745
# Better accuracy:0.7021276595744681
# Better accuracy:0.723404255319149
# Better accuracy:0.7446808510638298
# Better accuracy:0.7659574468085106
# Better accuracy:0.7872340425531915
# Better accuracy:0.8085106382978723
# Better accuracy:0.851063829787234
# Better accuracy:0.8723404255319149
# Better accuracy:0.8936170212765957
# Better accuracy:0.9148936170212766
# Better accuracy:0.9361702127659575
# Better accuracy:0.9574468085106383
# Better accuracy:0.9787234042553191
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.037037037037037035
# Better accuracy:0.1111111111111111
# Better accuracy:0.14814814814814814
# Better accuracy:0.2222222222222222
# Better accuracy:0.25925925925925924
# Better accuracy:0.2962962962962963
# Better accuracy:0.3333333333333333
# Better accuracy:0.37037037037037035
# Better accuracy:0.4074074074074074
# Better accuracy:0.4444444444444444
# Better accuracy:0.48148148148148145
# Better accuracy:0.7037037037037037
# Better accuracy:0.7777777777777778
# Better accuracy:0.8148148148148148
# Better accuracy:0.8518518518518519
# Better accuracy:0.8888888888888888
# Better accuracy:0.9259259259259259
# Better accuracy:0.9629629629629629
# Better accuracy:1.0
# initial_accuracy: 0.5319148936170213
# Better accuracy:0.5531914893617021
# Better accuracy:0.574468085106383
# Better accuracy:0.7021276595744681
# Better accuracy:0.723404255319149
# Better accuracy:0.7446808510638298
# Better accuracy:0.7659574468085106
# Better accuracy:0.7872340425531915
# Better accuracy:0.8085106382978723
# Better accuracy:0.851063829787234
# Better accuracy:0.8723404255319149
# Better accuracy:0.8936170212765957
# Better accuracy:0.9148936170212766
# Better accuracy:0.9361702127659575
# Better accuracy:0.9574468085106383
# Better accuracy:0.9787234042553191
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.037037037037037035
# Better accuracy:0.1111111111111111
# Better accuracy:0.14814814814814814
# Better accuracy:0.2222222222222222
# Better accuracy:0.2962962962962963
# Better accuracy:0.3333333333333333
# Better accuracy:0.37037037037037035
# Better accuracy:0.4444444444444444
# Better accuracy:0.48148148148148145
# Better accuracy:0.5185185185185185
# Better accuracy:0.8148148148148148
# Better accuracy:0.8518518518518519
# Better accuracy:0.8888888888888888
# Better accuracy:0.9259259259259259
# Better accuracy:0.9629629629629629
# Better accuracy:1.0
# initial_accuracy: 0.02127659574468085
# Better accuracy:0.0425531914893617
# Better accuracy:0.06382978723404255
# Better accuracy:0.0851063829787234
# Better accuracy:0.10638297872340426
# Better accuracy:0.851063829787234
# Better accuracy:0.8723404255319149
# Better accuracy:0.8936170212765957
# Better accuracy:0.9148936170212766
# Better accuracy:0.9361702127659575
# Better accuracy:0.9574468085106383
# Better accuracy:0.9787234042553191
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.037037037037037035
# Better accuracy:0.14814814814814814
# Better accuracy:0.18518518518518517
# Better accuracy:0.2222222222222222
# Better accuracy:0.2962962962962963
# Better accuracy:0.3333333333333333
# Better accuracy:0.4074074074074074
# Better accuracy:0.5555555555555556
# Better accuracy:0.6296296296296297
# Better accuracy:0.6666666666666666
# Better accuracy:0.7407407407407407
# Better accuracy:0.8148148148148148
# Better accuracy:0.8518518518518519
# Better accuracy:0.8888888888888888
# Better accuracy:0.9259259259259259
# Better accuracy:0.9629629629629629
# Better accuracy:1.0
# initial_accuracy: 0.0425531914893617
# Better accuracy:0.06382978723404255
# initial_accuracy: 0.0
# Better accuracy:0.574468085106383
# Better accuracy:0.5957446808510638
# Better accuracy:0.6170212765957447
# Better accuracy:0.8085106382978723
# Better accuracy:0.8297872340425532
# Better accuracy:0.851063829787234
# Better accuracy:0.8723404255319149
# Better accuracy:0.8936170212765957
# Better accuracy:0.9148936170212766
# Better accuracy:0.9361702127659575
# Better accuracy:0.9574468085106383
# Better accuracy:0.9787234042553191
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.037037037037037035
# Better accuracy:0.18518518518518517
# Better accuracy:0.2222222222222222
# Better accuracy:0.25925925925925924
# Better accuracy:0.3333333333333333
# Better accuracy:0.37037037037037035
# Better accuracy:0.4074074074074074
# Better accuracy:0.5555555555555556
# Better accuracy:0.6296296296296297
# Better accuracy:0.6666666666666666
# Better accuracy:0.7407407407407407
# Better accuracy:0.8148148148148148
# Better accuracy:0.8518518518518519
# Better accuracy:0.8888888888888888
# Better accuracy:0.9259259259259259
# Better accuracy:0.9629629629629629
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.5531914893617021
# Better accuracy:0.574468085106383
# Better accuracy:0.8723404255319149
# Better accuracy:0.8936170212765957
# Better accuracy:0.9148936170212766
# Better accuracy:0.9361702127659575
# Better accuracy:0.9574468085106383
# Better accuracy:0.9787234042553191
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.037037037037037035
# Better accuracy:0.07407407407407407
# Better accuracy:0.18518518518518517
# Better accuracy:0.2222222222222222
# Better accuracy:0.25925925925925924
# Better accuracy:0.37037037037037035
# Better accuracy:0.4444444444444444
# Better accuracy:0.48148148148148145
# Better accuracy:0.6666666666666666
# Better accuracy:0.7407407407407407
# Better accuracy:0.8148148148148148
# Better accuracy:0.8518518518518519
# Better accuracy:0.8888888888888888
# Better accuracy:0.9259259259259259
# Better accuracy:0.9629629629629629
# Better accuracy:1.0
# initial_accuracy: 0.02127659574468085
# Better accuracy:0.8936170212765957
# Better accuracy:0.9148936170212766
# Better accuracy:0.9361702127659575
# Better accuracy:0.9574468085106383
# Better accuracy:0.9787234042553191
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.8936170212765957
# Better accuracy:0.9148936170212766
# Better accuracy:0.9361702127659575
# Better accuracy:0.9574468085106383
# Better accuracy:0.9787234042553191
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.46808510638297873
# Better accuracy:0.48936170212765956
# Better accuracy:0.8936170212765957
# Better accuracy:0.9148936170212766
# Better accuracy:0.9361702127659575
# Better accuracy:0.9574468085106383
# Better accuracy:0.9787234042553191
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.037037037037037035
# Better accuracy:0.07407407407407407
# Better accuracy:0.25925925925925924
# Better accuracy:0.4074074074074074
# Better accuracy:0.48148148148148145
# Better accuracy:0.5185185185185185
# Better accuracy:0.6666666666666666
# Better accuracy:0.7407407407407407
# Better accuracy:0.7777777777777778
# Better accuracy:0.8148148148148148
# Better accuracy:0.8518518518518519
# Better accuracy:0.8888888888888888
# Better accuracy:0.9629629629629629
# Better accuracy:1.0
# initial_accuracy: 0.0425531914893617
# Better accuracy:0.8297872340425532
# Better accuracy:0.851063829787234
# Better accuracy:0.9361702127659575
# Better accuracy:0.9574468085106383
# Better accuracy:0.9787234042553191
# Better accuracy:1.0
# initial_accuracy: 0.0
# initial_accuracy: 0.037037037037037035
# Better accuracy:0.1111111111111111
# Better accuracy:0.2222222222222222
# Better accuracy:0.3333333333333333
# Better accuracy:0.48148148148148145
# Better accuracy:0.7407407407407407
# Better accuracy:0.8148148148148148
# Better accuracy:0.8888888888888888
# Better accuracy:0.9259259259259259
# initial_accuracy: 0.02127659574468085
# Better accuracy:0.06382978723404255
# Better accuracy:0.9574468085106383
# Better accuracy:0.9787234042553191
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.1111111111111111
# Better accuracy:0.2962962962962963
# Better accuracy:0.5185185185185185
# Better accuracy:0.7407407407407407
# Better accuracy:0.8148148148148148
# Better accuracy:0.8888888888888888
# Better accuracy:0.9629629629629629
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.1111111111111111
# Better accuracy:0.2962962962962963
# Better accuracy:0.5185185185185185
# Better accuracy:0.7407407407407407
# Better accuracy:0.8148148148148148
# Better accuracy:0.8888888888888888
# Better accuracy:0.9629629629629629
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.1111111111111111
# Better accuracy:0.2962962962962963
# Better accuracy:0.5185185185185185
# Better accuracy:0.7407407407407407
# Better accuracy:0.8148148148148148
# Better accuracy:0.8888888888888888
# Better accuracy:0.9629629629629629
# initial_accuracy: 0.0
# Better accuracy:0.037037037037037035
# Better accuracy:0.1111111111111111
# Better accuracy:0.3333333333333333
# Better accuracy:0.5555555555555556
# Better accuracy:0.7777777777777778
# Better accuracy:0.8518518518518519
# Better accuracy:0.9259259259259259
# initial_accuracy: 0.037037037037037035
# Better accuracy:0.14814814814814814
# Better accuracy:0.37037037037037035
# Better accuracy:0.5925925925925926
# Better accuracy:0.8518518518518519
# Better accuracy:0.9259259259259259
# initial_accuracy: 0.0
# Better accuracy:0.037037037037037035
# Better accuracy:0.14814814814814814
# Better accuracy:0.4074074074074074
# Better accuracy:0.6296296296296297
# Better accuracy:0.6666666666666666
# Better accuracy:0.9259259259259259
# initial_accuracy: 0.037037037037037035
# Better accuracy:0.07407407407407407
# Better accuracy:0.18518518518518517
# Better accuracy:0.48148148148148145
# Better accuracy:0.7037037037037037
# Better accuracy:0.7407407407407407
# initial_accuracy: 0.07407407407407407
# Better accuracy:0.25925925925925924
# Better accuracy:0.2962962962962963
# Better accuracy:0.7407407407407407
# initial_accuracy: 0.037037037037037035
# Better accuracy:0.25925925925925924
# Better accuracy:0.2962962962962963
# initial_accuracy: 0.6666666666666666
# Better accuracy:0.8888888888888888
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.02127659574468085
# Better accuracy:0.8085106382978723
# initial_accuracy: 0.0
# Better accuracy:0.19148936170212766
# after pruning: 200
# Number of Rules after pruning 31
# Accuracy of Test Data With Rules 0.8586956521739131
# f1_score of Test Data With Rules 0.8219178082191781
# recall_score of Test Data With Rules 0.7894736842105263
# before pruning: 264
# initial_accuracy: 0.9148936170212766
# Better accuracy:0.9787234042553191
# initial_accuracy: 0.07407407407407407
# Better accuracy:0.2222222222222222
# Better accuracy:0.25925925925925924
# Better accuracy:0.2962962962962963
# Better accuracy:0.4074074074074074
# Better accuracy:0.48148148148148145
# Better accuracy:0.5555555555555556
# Better accuracy:0.6296296296296297
# Better accuracy:0.6666666666666666
# Better accuracy:0.7037037037037037
# Better accuracy:0.8148148148148148
# Better accuracy:0.8518518518518519
# Better accuracy:0.9259259259259259
# Better accuracy:1.0
# initial_accuracy: 0.06382978723404255
# Better accuracy:0.46808510638297873
# Better accuracy:0.9361702127659575
# Better accuracy:0.9787234042553191
# initial_accuracy: 0.0
# Better accuracy:0.037037037037037035
# Better accuracy:0.1111111111111111
# Better accuracy:0.14814814814814814
# Better accuracy:0.2962962962962963
# Better accuracy:0.4074074074074074
# Better accuracy:0.48148148148148145
# Better accuracy:0.5555555555555556
# Better accuracy:0.6296296296296297
# Better accuracy:0.6666666666666666
# Better accuracy:0.7037037037037037
# Better accuracy:0.8148148148148148
# Better accuracy:0.8518518518518519
# Better accuracy:0.9259259259259259
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.9361702127659575
# Better accuracy:0.9787234042553191
# initial_accuracy: 0.0
# Better accuracy:0.037037037037037035
# Better accuracy:0.1111111111111111
# Better accuracy:0.2962962962962963
# Better accuracy:0.4074074074074074
# Better accuracy:0.48148148148148145
# Better accuracy:0.5555555555555556
# Better accuracy:0.6296296296296297
# Better accuracy:0.6666666666666666
# Better accuracy:0.7037037037037037
# Better accuracy:0.8148148148148148
# Better accuracy:0.8518518518518519
# Better accuracy:0.9259259259259259
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.18518518518518517
# Better accuracy:0.25925925925925924
# Better accuracy:0.3333333333333333
# Better accuracy:0.4444444444444444
# Better accuracy:0.5185185185185185
# Better accuracy:0.5925925925925926
# Better accuracy:0.6666666666666666
# Better accuracy:0.7037037037037037
# Better accuracy:0.7407407407407407
# Better accuracy:0.8518518518518519
# Better accuracy:0.8888888888888888
# Better accuracy:0.9259259259259259
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.23404255319148937
# Better accuracy:0.9787234042553191
# initial_accuracy: 0.0
# Better accuracy:0.9787234042553191
# initial_accuracy: 0.07407407407407407
# Better accuracy:0.1111111111111111
# Better accuracy:0.37037037037037035
# Better accuracy:0.48148148148148145
# Better accuracy:0.5555555555555556
# Better accuracy:0.6296296296296297
# Better accuracy:0.7037037037037037
# Better accuracy:0.7777777777777778
# Better accuracy:0.8148148148148148
# Better accuracy:0.8518518518518519
# Better accuracy:0.9259259259259259
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.06382978723404255
# Better accuracy:0.9787234042553191
# initial_accuracy: 0.0
# Better accuracy:0.4074074074074074
# Better accuracy:0.5185185185185185
# Better accuracy:0.5925925925925926
# Better accuracy:0.6666666666666666
# Better accuracy:0.7407407407407407
# Better accuracy:0.8518518518518519
# Better accuracy:0.8888888888888888
# Better accuracy:0.9259259259259259
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.4074074074074074
# Better accuracy:0.5185185185185185
# Better accuracy:0.5925925925925926
# Better accuracy:0.6666666666666666
# Better accuracy:0.7407407407407407
# Better accuracy:0.8518518518518519
# Better accuracy:0.8888888888888888
# Better accuracy:0.9259259259259259
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.4074074074074074
# Better accuracy:0.5185185185185185
# Better accuracy:0.5925925925925926
# Better accuracy:0.6666666666666666
# Better accuracy:0.7407407407407407
# Better accuracy:0.8518518518518519
# Better accuracy:0.8888888888888888
# Better accuracy:0.9259259259259259
# initial_accuracy: 0.0
# Better accuracy:0.037037037037037035
# Better accuracy:0.4074074074074074
# Better accuracy:0.5185185185185185
# Better accuracy:0.5925925925925926
# Better accuracy:0.7037037037037037
# Better accuracy:0.7777777777777778
# Better accuracy:0.8148148148148148
# Better accuracy:0.9259259259259259
# initial_accuracy: 0.0
# Better accuracy:0.037037037037037035
# Better accuracy:0.4074074074074074
# Better accuracy:0.5555555555555556
# Better accuracy:0.6296296296296297
# Better accuracy:0.7407407407407407
# Better accuracy:0.8148148148148148
# Better accuracy:0.8888888888888888
# initial_accuracy: 0.0
# Better accuracy:0.037037037037037035
# Better accuracy:0.4074074074074074
# Better accuracy:0.4444444444444444
# Better accuracy:0.5555555555555556
# Better accuracy:0.7037037037037037
# Better accuracy:0.8888888888888888
# initial_accuracy: 0.0
# Better accuracy:0.1702127659574468
# Better accuracy:0.9787234042553191
# Better accuracy:1.0
# initial_accuracy: 0.07407407407407407
# Better accuracy:0.1111111111111111
# Better accuracy:0.48148148148148145
# Better accuracy:0.5555555555555556
# Better accuracy:0.6296296296296297
# Better accuracy:0.8148148148148148
# Better accuracy:1.0
# initial_accuracy: 0.07407407407407407
# Better accuracy:0.14814814814814814
# Better accuracy:0.5555555555555556
# Better accuracy:0.7037037037037037
# initial_accuracy: 0.14814814814814814
# Better accuracy:0.2962962962962963
# Better accuracy:0.7037037037037037
# initial_accuracy: 0.25925925925925924
# Better accuracy:0.8888888888888888
# Better accuracy:1.0
# initial_accuracy: 0.0
# initial_accuracy: 0.037037037037037035
# Better accuracy:0.07407407407407407
# Better accuracy:0.25925925925925924
# Better accuracy:0.9259259259259259
# Better accuracy:1.0
# initial_accuracy: 0.0
# initial_accuracy: 0.0
# Better accuracy:0.3191489361702128
# after pruning: 146
# Number of Rules after pruning 26
# Accuracy of Test Data With Rules 0.8804347826086957
# f1_score of Test Data With Rules 0.8641975308641975
# recall_score of Test Data With Rules 0.8974358974358975
# before pruning: 563
# initial_accuracy: 0.18
# Better accuracy:0.2
# Better accuracy:0.38
# Better accuracy:0.4
# Better accuracy:0.62
# Better accuracy:0.64
# Better accuracy:0.78
# Better accuracy:0.8
# Better accuracy:0.82
# Better accuracy:0.86
# Better accuracy:0.88
# Better accuracy:0.9
# Better accuracy:0.92
# Better accuracy:0.94
# Better accuracy:0.96
# Better accuracy:0.98
# initial_accuracy: 0.0
# Better accuracy:0.08333333333333333
# Better accuracy:0.125
# Better accuracy:0.16666666666666666
# Better accuracy:0.20833333333333334
# Better accuracy:0.25
# Better accuracy:0.2916666666666667
# Better accuracy:0.3333333333333333
# Better accuracy:0.375
# Better accuracy:0.5
# Better accuracy:0.5416666666666666
# Better accuracy:0.5833333333333334
# Better accuracy:0.625
# Better accuracy:0.6666666666666666
# Better accuracy:0.75
# Better accuracy:0.7916666666666666
# Better accuracy:0.8333333333333334
# Better accuracy:0.875
# Better accuracy:0.9166666666666666
# Better accuracy:0.9583333333333334
# Better accuracy:1.0
# initial_accuracy: 0.44
# Better accuracy:0.46
# Better accuracy:0.6
# Better accuracy:0.62
# Better accuracy:0.64
# Better accuracy:0.78
# Better accuracy:0.8
# Better accuracy:0.82
# Better accuracy:0.86
# Better accuracy:0.88
# Better accuracy:0.9
# Better accuracy:0.92
# Better accuracy:0.94
# Better accuracy:0.96
# Better accuracy:0.98
# initial_accuracy: 0.0
# Better accuracy:0.125
# Better accuracy:0.16666666666666666
# Better accuracy:0.20833333333333334
# Better accuracy:0.25
# Better accuracy:0.2916666666666667
# Better accuracy:0.3333333333333333
# Better accuracy:0.375
# Better accuracy:0.5416666666666666
# Better accuracy:0.5833333333333334
# Better accuracy:0.625
# Better accuracy:0.6666666666666666
# Better accuracy:0.7083333333333334
# Better accuracy:0.7916666666666666
# Better accuracy:0.8333333333333334
# Better accuracy:0.875
# Better accuracy:0.9166666666666666
# Better accuracy:0.9583333333333334
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.06
# Better accuracy:0.08
# Better accuracy:0.1
# Better accuracy:0.88
# Better accuracy:0.9
# Better accuracy:0.92
# Better accuracy:0.94
# Better accuracy:0.96
# Better accuracy:0.98
# initial_accuracy: 0.0
# Better accuracy:0.125
# Better accuracy:0.16666666666666666
# Better accuracy:0.20833333333333334
# Better accuracy:0.25
# Better accuracy:0.2916666666666667
# Better accuracy:0.3333333333333333
# Better accuracy:0.375
# Better accuracy:0.4583333333333333
# Better accuracy:0.5
# Better accuracy:0.5833333333333334
# Better accuracy:0.625
# Better accuracy:0.6666666666666666
# Better accuracy:0.75
# Better accuracy:0.7916666666666666
# Better accuracy:0.8333333333333334
# Better accuracy:0.875
# Better accuracy:0.9166666666666666
# Better accuracy:0.9583333333333334
# Better accuracy:1.0
# initial_accuracy: 0.02
# Better accuracy:0.22
# Better accuracy:0.24
# Better accuracy:0.26
# Better accuracy:0.28
# initial_accuracy: 0.2
# Better accuracy:0.22
# Better accuracy:0.24
# Better accuracy:0.26
# Better accuracy:0.28
# initial_accuracy: 0.0
# Better accuracy:0.041666666666666664
# initial_accuracy: 0.02
# Better accuracy:0.38
# Better accuracy:0.4
# Better accuracy:0.88
# Better accuracy:0.9
# Better accuracy:0.92
# Better accuracy:0.94
# Better accuracy:0.96
# Better accuracy:0.98
# initial_accuracy: 0.0
# Better accuracy:0.125
# Better accuracy:0.16666666666666666
# Better accuracy:0.20833333333333334
# Better accuracy:0.25
# Better accuracy:0.2916666666666667
# Better accuracy:0.3333333333333333
# Better accuracy:0.4166666666666667
# Better accuracy:0.4583333333333333
# Better accuracy:0.5
# Better accuracy:0.7083333333333334
# Better accuracy:0.75
# Better accuracy:0.7916666666666666
# Better accuracy:0.8333333333333334
# Better accuracy:0.875
# Better accuracy:0.9166666666666666
# Better accuracy:0.9583333333333334
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.08333333333333333
# Better accuracy:0.125
# Better accuracy:0.16666666666666666
# Better accuracy:0.20833333333333334
# Better accuracy:0.25
# Better accuracy:0.2916666666666667
# Better accuracy:0.3333333333333333
# Better accuracy:0.4166666666666667
# Better accuracy:0.5
# Better accuracy:0.5416666666666666
# Better accuracy:0.5833333333333334
# Better accuracy:0.7916666666666666
# Better accuracy:0.8333333333333334
# Better accuracy:0.875
# Better accuracy:0.9166666666666666
# Better accuracy:0.9583333333333334
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.28
# Better accuracy:0.3
# Better accuracy:0.32
# Better accuracy:0.88
# Better accuracy:0.9
# Better accuracy:0.92
# Better accuracy:0.94
# Better accuracy:0.96
# Better accuracy:0.98
# initial_accuracy: 0.0
# Better accuracy:0.041666666666666664
# Better accuracy:0.08333333333333333
# Better accuracy:0.25
# Better accuracy:0.2916666666666667
# Better accuracy:0.3333333333333333
# Better accuracy:0.4166666666666667
# Better accuracy:0.4583333333333333
# Better accuracy:0.5416666666666666
# Better accuracy:0.5833333333333334
# Better accuracy:0.625
# Better accuracy:0.6666666666666666
# Better accuracy:0.7916666666666666
# Better accuracy:0.875
# Better accuracy:0.9166666666666666
# Better accuracy:0.9583333333333334
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.2
# Better accuracy:0.22
# Better accuracy:0.88
# Better accuracy:0.9
# Better accuracy:0.92
# Better accuracy:0.94
# Better accuracy:0.96
# Better accuracy:0.98
# initial_accuracy: 0.0
# Better accuracy:0.02
# Better accuracy:0.88
# Better accuracy:0.9
# Better accuracy:0.92
# Better accuracy:0.94
# Better accuracy:0.96
# Better accuracy:0.98
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.041666666666666664
# initial_accuracy: 0.0
# Better accuracy:0.82
# Better accuracy:0.84
# Better accuracy:0.88
# Better accuracy:0.9
# Better accuracy:0.92
# Better accuracy:0.94
# Better accuracy:0.96
# Better accuracy:0.98
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.041666666666666664
# Better accuracy:0.08333333333333333
# Better accuracy:0.16666666666666666
# Better accuracy:0.25
# Better accuracy:0.375
# Better accuracy:0.5
# Better accuracy:0.5416666666666666
# Better accuracy:0.5833333333333334
# Better accuracy:0.625
# Better accuracy:0.7083333333333334
# Better accuracy:0.75
# Better accuracy:0.8333333333333334
# Better accuracy:0.9166666666666666
# Better accuracy:0.9583333333333334
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.88
# Better accuracy:0.9
# Better accuracy:0.92
# Better accuracy:0.94
# Better accuracy:0.96
# Better accuracy:0.98
# Better accuracy:1.0
# initial_accuracy: 0.02
# Better accuracy:0.9
# Better accuracy:0.92
# Better accuracy:0.94
# Better accuracy:0.96
# Better accuracy:0.98
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.52
# Better accuracy:0.54
# Better accuracy:0.9
# Better accuracy:0.92
# Better accuracy:0.94
# Better accuracy:0.96
# Better accuracy:0.98
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.08333333333333333
# Better accuracy:0.16666666666666666
# Better accuracy:0.20833333333333334
# Better accuracy:0.2916666666666667
# Better accuracy:0.3333333333333333
# Better accuracy:0.4166666666666667
# Better accuracy:0.4583333333333333
# Better accuracy:0.5416666666666666
# Better accuracy:0.625
# Better accuracy:0.6666666666666666
# Better accuracy:0.7083333333333334
# Better accuracy:0.9166666666666666
# Better accuracy:0.9583333333333334
# Better accuracy:1.0
# initial_accuracy: 0.041666666666666664
# Better accuracy:0.20833333333333334
# Better accuracy:0.25
# Better accuracy:0.2916666666666667
# Better accuracy:0.3333333333333333
# Better accuracy:0.375
# Better accuracy:0.5
# Better accuracy:0.5416666666666666
# Better accuracy:0.625
# Better accuracy:0.6666666666666666
# Better accuracy:0.7083333333333334
# Better accuracy:0.8333333333333334
# Better accuracy:0.9166666666666666
# Better accuracy:0.9583333333333334
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.08
# Better accuracy:0.94
# Better accuracy:0.96
# Better accuracy:0.98
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.2916666666666667
# Better accuracy:0.375
# Better accuracy:0.4166666666666667
# Better accuracy:0.5
# Better accuracy:0.5416666666666666
# Better accuracy:0.625
# Better accuracy:0.6666666666666666
# Better accuracy:0.7083333333333334
# Better accuracy:0.8333333333333334
# Better accuracy:0.9166666666666666
# Better accuracy:0.9583333333333334
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.2916666666666667
# Better accuracy:0.375
# Better accuracy:0.4166666666666667
# Better accuracy:0.5
# Better accuracy:0.5416666666666666
# Better accuracy:0.625
# Better accuracy:0.6666666666666666
# Better accuracy:0.7083333333333334
# Better accuracy:0.8333333333333334
# Better accuracy:0.9166666666666666
# Better accuracy:0.9583333333333334
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.2916666666666667
# Better accuracy:0.375
# Better accuracy:0.4166666666666667
# Better accuracy:0.5
# Better accuracy:0.5416666666666666
# Better accuracy:0.625
# Better accuracy:0.6666666666666666
# Better accuracy:0.7083333333333334
# Better accuracy:0.8333333333333334
# Better accuracy:0.9166666666666666
# Better accuracy:0.9583333333333334
# initial_accuracy: 0.0
# Better accuracy:0.2916666666666667
# Better accuracy:0.375
# Better accuracy:0.4166666666666667
# Better accuracy:0.5
# Better accuracy:0.5416666666666666
# Better accuracy:0.625
# Better accuracy:0.7083333333333334
# Better accuracy:0.75
# Better accuracy:0.875
# Better accuracy:0.9583333333333334
# initial_accuracy: 0.0
# Better accuracy:0.041666666666666664
# Better accuracy:0.2916666666666667
# Better accuracy:0.375
# Better accuracy:0.4583333333333333
# Better accuracy:0.5
# Better accuracy:0.5833333333333334
# Better accuracy:0.625
# Better accuracy:0.7083333333333334
# Better accuracy:0.7916666666666666
# Better accuracy:0.875
# initial_accuracy: 0.041666666666666664
# Better accuracy:0.125
# Better accuracy:0.3333333333333333
# Better accuracy:0.5
# Better accuracy:0.5833333333333334
# Better accuracy:0.7083333333333334
# Better accuracy:0.7916666666666666
# Better accuracy:0.875
# initial_accuracy: 0.0
# Better accuracy:0.16666666666666666
# Better accuracy:0.3333333333333333
# Better accuracy:0.6666666666666666
# Better accuracy:0.75
# Better accuracy:0.875
# initial_accuracy: 0.16666666666666666
# Better accuracy:0.20833333333333334
# Better accuracy:0.5
# Better accuracy:0.875
# initial_accuracy: 0.08333333333333333
# Better accuracy:0.125
# Better accuracy:0.5833333333333334
# initial_accuracy: 0.375
# Better accuracy:0.9583333333333334
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.04
# Better accuracy:0.06
# Better accuracy:0.9
# Better accuracy:1.0
# initial_accuracy: 0.0
# initial_accuracy: 0.0
# Better accuracy:0.1
# after pruning: 306
# Number of Rules after pruning 38
# Accuracy of Test Data With Rules 0.782608695652174
# f1_score of Test Data With Rules 0.6774193548387097
# recall_score of Test Data With Rules 0.8076923076923077
# before pruning: 524
# initial_accuracy: 0.16326530612244897
# Better accuracy:0.1836734693877551
# Better accuracy:0.2653061224489796
# Better accuracy:0.2857142857142857
# Better accuracy:0.8163265306122449
# Better accuracy:0.9183673469387755
# Better accuracy:0.9387755102040817
# Better accuracy:0.9591836734693877
# Better accuracy:0.9795918367346939
# initial_accuracy: 0.0
# Better accuracy:0.08
# Better accuracy:0.12
# Better accuracy:0.16
# Better accuracy:0.2
# Better accuracy:0.24
# Better accuracy:0.28
# Better accuracy:0.32
# Better accuracy:0.4
# Better accuracy:0.48
# Better accuracy:0.52
# Better accuracy:0.56
# Better accuracy:0.6
# Better accuracy:0.64
# Better accuracy:0.68
# Better accuracy:0.72
# Better accuracy:0.76
# Better accuracy:0.8
# Better accuracy:0.88
# Better accuracy:0.92
# Better accuracy:0.96
# Better accuracy:1.0
# initial_accuracy: 0.6530612244897959
# Better accuracy:0.7551020408163265
# Better accuracy:0.8163265306122449
# Better accuracy:0.9183673469387755
# Better accuracy:0.9387755102040817
# Better accuracy:0.9591836734693877
# Better accuracy:0.9795918367346939
# initial_accuracy: 0.0
# Better accuracy:0.7755102040816326
# Better accuracy:0.8367346938775511
# Better accuracy:0.8571428571428571
# Better accuracy:0.9183673469387755
# Better accuracy:0.9387755102040817
# Better accuracy:0.9591836734693877
# Better accuracy:0.9795918367346939
# initial_accuracy: 0.04
# Better accuracy:0.08
# Better accuracy:0.12
# Better accuracy:0.16
# Better accuracy:0.2
# Better accuracy:0.24
# Better accuracy:0.28
# Better accuracy:0.32
# Better accuracy:0.36
# Better accuracy:0.44
# Better accuracy:0.48
# Better accuracy:0.56
# Better accuracy:0.64
# Better accuracy:0.68
# Better accuracy:0.72
# Better accuracy:0.76
# Better accuracy:0.8
# Better accuracy:0.84
# Better accuracy:0.88
# Better accuracy:0.92
# Better accuracy:0.96
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.04
# initial_accuracy: 0.0
# Better accuracy:0.4897959183673469
# Better accuracy:0.5714285714285714
# Better accuracy:0.8163265306122449
# Better accuracy:0.9183673469387755
# Better accuracy:0.9387755102040817
# Better accuracy:0.9591836734693877
# Better accuracy:0.9795918367346939
# Better accuracy:1.0
# initial_accuracy: 0.02040816326530612
# Better accuracy:0.2857142857142857
# Better accuracy:0.30612244897959184
# Better accuracy:0.8367346938775511
# Better accuracy:0.9387755102040817
# Better accuracy:0.9591836734693877
# Better accuracy:0.9795918367346939
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.12
# Better accuracy:0.2
# Better accuracy:0.24
# Better accuracy:0.32
# Better accuracy:0.4
# Better accuracy:0.48
# Better accuracy:0.52
# Better accuracy:0.64
# Better accuracy:0.68
# Better accuracy:0.72
# Better accuracy:0.76
# Better accuracy:0.8
# Better accuracy:0.84
# Better accuracy:0.88
# Better accuracy:0.96
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.5714285714285714
# Better accuracy:0.6326530612244898
# Better accuracy:0.8367346938775511
# Better accuracy:0.9387755102040817
# Better accuracy:0.9591836734693877
# Better accuracy:0.9795918367346939
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.08
# Better accuracy:0.12
# Better accuracy:0.16
# Better accuracy:0.2
# Better accuracy:0.24
# Better accuracy:0.28
# Better accuracy:0.32
# Better accuracy:0.36
# Better accuracy:0.4
# Better accuracy:0.44
# Better accuracy:0.52
# Better accuracy:0.6
# Better accuracy:0.68
# Better accuracy:0.76
# Better accuracy:0.8
# Better accuracy:0.84
# Better accuracy:0.88
# Better accuracy:0.96
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.6326530612244898
# Better accuracy:0.7142857142857143
# Better accuracy:0.8367346938775511
# Better accuracy:0.9387755102040817
# Better accuracy:0.9591836734693877
# Better accuracy:0.9795918367346939
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.04
# Better accuracy:0.08
# Better accuracy:0.12
# Better accuracy:0.16
# Better accuracy:0.2
# Better accuracy:0.24
# Better accuracy:0.28
# Better accuracy:0.32
# Better accuracy:0.4
# Better accuracy:0.44
# Better accuracy:0.52
# Better accuracy:0.6
# Better accuracy:0.68
# Better accuracy:0.76
# Better accuracy:0.8
# Better accuracy:0.84
# Better accuracy:0.88
# Better accuracy:0.96
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.7551020408163265
# Better accuracy:0.8367346938775511
# Better accuracy:0.8571428571428571
# Better accuracy:0.9387755102040817
# Better accuracy:0.9591836734693877
# Better accuracy:0.9795918367346939
# Better accuracy:1.0
# initial_accuracy: 0.0
# initial_accuracy: 0.0
# Better accuracy:0.8367346938775511
# Better accuracy:0.9387755102040817
# Better accuracy:0.9591836734693877
# Better accuracy:0.9795918367346939
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.8367346938775511
# Better accuracy:0.9387755102040817
# Better accuracy:0.9591836734693877
# Better accuracy:0.9795918367346939
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.5918367346938775
# Better accuracy:0.6326530612244898
# Better accuracy:0.8367346938775511
# Better accuracy:0.9387755102040817
# Better accuracy:0.9591836734693877
# Better accuracy:0.9795918367346939
# Better accuracy:1.0
# initial_accuracy: 0.08
# Better accuracy:0.12
# Better accuracy:0.2
# Better accuracy:0.28
# Better accuracy:0.36
# Better accuracy:0.44
# Better accuracy:0.48
# Better accuracy:0.6
# Better accuracy:0.64
# Better accuracy:0.68
# Better accuracy:0.76
# Better accuracy:0.8
# Better accuracy:0.84
# Better accuracy:0.88
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.24
# Better accuracy:0.32
# Better accuracy:0.4
# Better accuracy:0.44
# Better accuracy:0.52
# Better accuracy:0.6
# Better accuracy:0.68
# Better accuracy:0.76
# Better accuracy:0.8
# Better accuracy:0.84
# Better accuracy:0.88
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.24
# Better accuracy:0.32
# Better accuracy:0.44
# Better accuracy:0.48
# Better accuracy:0.56
# Better accuracy:0.64
# Better accuracy:0.72
# Better accuracy:0.76
# Better accuracy:0.8
# Better accuracy:0.84
# Better accuracy:0.88
# Better accuracy:0.96
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.24
# Better accuracy:0.32
# Better accuracy:0.36
# Better accuracy:0.44
# Better accuracy:0.48
# Better accuracy:0.52
# initial_accuracy: 0.0
# initial_accuracy: 0.0
# Better accuracy:0.24
# Better accuracy:0.32
# Better accuracy:0.4
# Better accuracy:0.44
# Better accuracy:0.52
# Better accuracy:0.6
# Better accuracy:0.68
# Better accuracy:0.76
# Better accuracy:0.88
# Better accuracy:0.96
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.24
# Better accuracy:0.32
# Better accuracy:0.4
# Better accuracy:0.44
# Better accuracy:0.52
# Better accuracy:0.6
# Better accuracy:0.68
# Better accuracy:0.76
# Better accuracy:0.88
# Better accuracy:0.96
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.24
# Better accuracy:0.32
# Better accuracy:0.4
# Better accuracy:0.44
# Better accuracy:0.52
# Better accuracy:0.6
# Better accuracy:0.68
# Better accuracy:0.76
# Better accuracy:0.88
# Better accuracy:0.96
# initial_accuracy: 0.0
# Better accuracy:0.04
# Better accuracy:0.24
# Better accuracy:0.36
# Better accuracy:0.44
# Better accuracy:0.48
# Better accuracy:0.56
# Better accuracy:0.64
# Better accuracy:0.72
# Better accuracy:0.8
# Better accuracy:0.92
# initial_accuracy: 0.04
# Better accuracy:0.08
# Better accuracy:0.28
# Better accuracy:0.44
# Better accuracy:0.56
# Better accuracy:0.68
# Better accuracy:0.72
# Better accuracy:0.92
# initial_accuracy: 0.08
# Better accuracy:0.12
# Better accuracy:0.36
# Better accuracy:0.56
# Better accuracy:0.68
# Better accuracy:0.8
# Better accuracy:0.92
# initial_accuracy: 0.04
# Better accuracy:0.4
# Better accuracy:0.6
# Better accuracy:0.72
# Better accuracy:0.88
# initial_accuracy: 0.12
# Better accuracy:0.28
# Better accuracy:0.52
# Better accuracy:0.88
# initial_accuracy: 0.0
# Better accuracy:0.12
# Better accuracy:0.52
# initial_accuracy: 0.48
# Better accuracy:0.96
# Better accuracy:1.0
# initial_accuracy: 0.02040816326530612
# Better accuracy:0.3673469387755102
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.10204081632653061
# after pruning: 305
# Number of Rules after pruning 35
# Accuracy of Test Data With Rules 0.9021739130434783
# f1_score of Test Data With Rules 0.8615384615384616
# recall_score of Test Data With Rules 0.8
# before pruning: 440
# initial_accuracy: 0.11363636363636363
# Better accuracy:0.4090909090909091
# Better accuracy:0.4318181818181818
# Better accuracy:0.6363636363636364
# Better accuracy:0.6590909090909091
# Better accuracy:0.6818181818181818
# Better accuracy:0.7272727272727273
# Better accuracy:0.75
# Better accuracy:0.8181818181818182
# Better accuracy:0.8636363636363636
# Better accuracy:0.8863636363636364
# Better accuracy:0.9090909090909091
# Better accuracy:0.9318181818181818
# Better accuracy:0.9545454545454546
# initial_accuracy: 0.0
# Better accuracy:0.1
# Better accuracy:0.2
# Better accuracy:0.23333333333333334
# Better accuracy:0.3
# Better accuracy:0.36666666666666664
# Better accuracy:0.4
# initial_accuracy: 0.5227272727272727
# Better accuracy:0.5454545454545454
# Better accuracy:0.5681818181818182
# Better accuracy:0.6136363636363636
# Better accuracy:0.6363636363636364
# Better accuracy:0.6590909090909091
# Better accuracy:0.6818181818181818
# Better accuracy:0.7272727272727273
# Better accuracy:0.75
# Better accuracy:0.8181818181818182
# Better accuracy:0.8636363636363636
# Better accuracy:0.8863636363636364
# Better accuracy:0.9090909090909091
# Better accuracy:0.9318181818181818
# Better accuracy:0.9545454545454546
# initial_accuracy: 0.0
# Better accuracy:0.13333333333333333
# Better accuracy:0.23333333333333334
# Better accuracy:0.26666666666666666
# Better accuracy:0.3333333333333333
# Better accuracy:0.4
# initial_accuracy: 0.09090909090909091
# Better accuracy:0.11363636363636363
# Better accuracy:0.13636363636363635
# Better accuracy:0.1590909090909091
# Better accuracy:0.18181818181818182
# Better accuracy:0.8863636363636364
# Better accuracy:0.9090909090909091
# Better accuracy:0.9318181818181818
# Better accuracy:0.9545454545454546
# initial_accuracy: 0.0
# Better accuracy:0.03333333333333333
# Better accuracy:0.2
# Better accuracy:0.3333333333333333
# Better accuracy:0.4
# Better accuracy:0.43333333333333335
# Better accuracy:0.4666666666666667
# Better accuracy:0.5
# Better accuracy:0.6
# Better accuracy:0.7
# Better accuracy:0.7333333333333333
# Better accuracy:0.7666666666666667
# Better accuracy:0.8
# Better accuracy:0.8333333333333334
# initial_accuracy: 0.06818181818181818
# Better accuracy:0.09090909090909091
# Better accuracy:0.36363636363636365
# Better accuracy:0.38636363636363635
# Better accuracy:0.8181818181818182
# Better accuracy:0.8636363636363636
# Better accuracy:0.8863636363636364
# Better accuracy:0.9090909090909091
# Better accuracy:0.9318181818181818
# Better accuracy:0.9545454545454546
# initial_accuracy: 0.022727272727272728
# Better accuracy:0.7727272727272727
# Better accuracy:0.7954545454545454
# Better accuracy:0.8409090909090909
# Better accuracy:0.8863636363636364
# Better accuracy:0.9090909090909091
# Better accuracy:0.9318181818181818
# Better accuracy:0.9545454545454546
# initial_accuracy: 0.0
# Better accuracy:0.03333333333333333
# Better accuracy:0.23333333333333334
# Better accuracy:0.36666666666666664
# Better accuracy:0.43333333333333335
# Better accuracy:0.4666666666666667
# Better accuracy:0.5
# Better accuracy:0.5333333333333333
# Better accuracy:0.6333333333333333
# Better accuracy:0.7333333333333333
# Better accuracy:0.7666666666666667
# Better accuracy:0.8
# Better accuracy:0.8333333333333334
# initial_accuracy: 0.0
# initial_accuracy: 0.022727272727272728
# Better accuracy:0.6363636363636364
# Better accuracy:0.6590909090909091
# Better accuracy:0.8636363636363636
# Better accuracy:0.9090909090909091
# Better accuracy:0.9318181818181818
# Better accuracy:0.9545454545454546
# initial_accuracy: 0.0
# Better accuracy:0.23333333333333334
# Better accuracy:0.36666666666666664
# Better accuracy:0.43333333333333335
# Better accuracy:0.4666666666666667
# Better accuracy:0.5
# Better accuracy:0.5333333333333333
# Better accuracy:0.5666666666666667
# Better accuracy:0.7
# Better accuracy:0.8
# Better accuracy:0.8333333333333334
# initial_accuracy: 0.0
# Better accuracy:0.022727272727272728
# initial_accuracy: 0.022727272727272728
# Better accuracy:0.6818181818181818
# Better accuracy:0.7045454545454546
# Better accuracy:0.8863636363636364
# Better accuracy:0.9318181818181818
# Better accuracy:0.9545454545454546
# Better accuracy:0.9772727272727273
# initial_accuracy: 0.0
# Better accuracy:0.13333333333333333
# Better accuracy:0.2
# Better accuracy:0.23333333333333334
# Better accuracy:0.36666666666666664
# Better accuracy:0.4666666666666667
# Better accuracy:0.5
# Better accuracy:0.5333333333333333
# Better accuracy:0.5666666666666667
# Better accuracy:0.6
# Better accuracy:0.6666666666666666
# Better accuracy:0.7666666666666667
# Better accuracy:0.8
# Better accuracy:0.8333333333333334
# initial_accuracy: 0.0
# Better accuracy:0.8863636363636364
# Better accuracy:0.9318181818181818
# Better accuracy:0.9545454545454546
# Better accuracy:0.9772727272727273
# initial_accuracy: 0.0
# Better accuracy:0.03333333333333333
# Better accuracy:0.13333333333333333
# Better accuracy:0.23333333333333334
# Better accuracy:0.26666666666666666
# Better accuracy:0.43333333333333335
# Better accuracy:0.5333333333333333
# Better accuracy:0.5666666666666667
# Better accuracy:0.6
# Better accuracy:0.6333333333333333
# Better accuracy:0.6666666666666666
# Better accuracy:0.7
# Better accuracy:0.7333333333333333
# Better accuracy:0.8
# Better accuracy:0.8333333333333334
# initial_accuracy: 0.0
# Better accuracy:0.18181818181818182
# Better accuracy:0.20454545454545456
# Better accuracy:0.8863636363636364
# Better accuracy:0.9318181818181818
# Better accuracy:0.9545454545454546
# Better accuracy:0.9772727272727273
# initial_accuracy: 0.0
# Better accuracy:0.5
# Better accuracy:0.5227272727272727
# Better accuracy:0.8863636363636364
# Better accuracy:0.9318181818181818
# Better accuracy:0.9545454545454546
# Better accuracy:0.9772727272727273
# initial_accuracy: 0.03333333333333333
# Better accuracy:0.06666666666666667
# Better accuracy:0.2
# Better accuracy:0.3333333333333333
# Better accuracy:0.5
# Better accuracy:0.5666666666666667
# Better accuracy:0.6333333333333333
# Better accuracy:0.6666666666666666
# Better accuracy:0.7
# Better accuracy:0.7333333333333333
# Better accuracy:0.8
# Better accuracy:0.8333333333333334
# initial_accuracy: 0.0
# Better accuracy:0.03333333333333333
# Better accuracy:0.16666666666666666
# Better accuracy:0.3333333333333333
# Better accuracy:0.36666666666666664
# Better accuracy:0.4666666666666667
# Better accuracy:0.5333333333333333
# Better accuracy:0.6333333333333333
# Better accuracy:0.7333333333333333
# Better accuracy:0.8
# Better accuracy:0.8333333333333334
# Better accuracy:0.9
# Better accuracy:0.9333333333333333
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.13636363636363635
# Better accuracy:0.1590909090909091
# Better accuracy:0.8863636363636364
# Better accuracy:0.9318181818181818
# Better accuracy:0.9545454545454546
# Better accuracy:0.9772727272727273
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.26666666666666666
# Better accuracy:0.4666666666666667
# Better accuracy:0.5333333333333333
# Better accuracy:0.6333333333333333
# Better accuracy:0.7333333333333333
# Better accuracy:0.8
# Better accuracy:0.8333333333333334
# Better accuracy:0.9
# Better accuracy:0.9333333333333333
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.26666666666666666
# Better accuracy:0.4666666666666667
# Better accuracy:0.5333333333333333
# Better accuracy:0.6333333333333333
# Better accuracy:0.7333333333333333
# Better accuracy:0.8
# Better accuracy:0.8333333333333334
# Better accuracy:0.9
# Better accuracy:0.9333333333333333
# initial_accuracy: 0.03333333333333333
# Better accuracy:0.3
# Better accuracy:0.5
# Better accuracy:0.5666666666666667
# Better accuracy:0.7
# Better accuracy:0.8
# Better accuracy:0.8666666666666667
# Better accuracy:0.9333333333333333
# initial_accuracy: 0.0
# Better accuracy:0.03333333333333333
# Better accuracy:0.3
# Better accuracy:0.5333333333333333
# Better accuracy:0.6333333333333333
# Better accuracy:0.8
# Better accuracy:0.9333333333333333
# initial_accuracy: 0.06666666666666667
# Better accuracy:0.26666666666666666
# Better accuracy:0.36666666666666664
# Better accuracy:0.8
# Better accuracy:0.9333333333333333
# initial_accuracy: 0.03333333333333333
# Better accuracy:0.4
# Better accuracy:0.8333333333333334
# initial_accuracy: 0.06666666666666667
# Better accuracy:0.16666666666666666
# Better accuracy:0.4666666666666667
# initial_accuracy: 0.0
# Better accuracy:0.03333333333333333
# Better accuracy:0.06666666666666667
# initial_accuracy: 0.0
# Better accuracy:0.022727272727272728
# Better accuracy:0.22727272727272727
# Better accuracy:0.29545454545454547
# Better accuracy:0.3181818181818182
# Better accuracy:0.7045454545454546
# Better accuracy:0.7727272727272727
# Better accuracy:0.8181818181818182
# Better accuracy:1.0
# initial_accuracy: 0.4666666666666667
# Better accuracy:0.9
# Better accuracy:0.9333333333333333
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.045454545454545456
# Better accuracy:0.7045454545454546
# Better accuracy:0.7727272727272727
# Better accuracy:0.8181818181818182
# Better accuracy:1.0
# initial_accuracy: 0.022727272727272728
# Better accuracy:0.11363636363636363
# Better accuracy:0.22727272727272727
# Better accuracy:0.8181818181818182
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.18181818181818182
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.06818181818181818
# after pruning: 246
# Number of Rules after pruning 36
# Accuracy of Test Data With Rules 0.9021739130434783
# f1_score of Test Data With Rules 0.8767123287671232
# recall_score of Test Data With Rules 0.8205128205128205
# before pruning: 397
# initial_accuracy: 0.17777777777777778
# Better accuracy:0.37777777777777777
# Better accuracy:0.4
# Better accuracy:0.6444444444444445
# Better accuracy:0.6888888888888889
# Better accuracy:0.7111111111111111
# Better accuracy:0.7777777777777778
# Better accuracy:0.8444444444444444
# Better accuracy:0.9111111111111111
# Better accuracy:0.9777777777777777
# Better accuracy:1.0
# initial_accuracy: 0.0
# initial_accuracy: 0.4666666666666667
# Better accuracy:0.5111111111111111
# Better accuracy:0.5333333333333333
# Better accuracy:0.6
# Better accuracy:0.6444444444444445
# Better accuracy:0.6888888888888889
# Better accuracy:0.7111111111111111
# Better accuracy:0.7777777777777778
# Better accuracy:0.8444444444444444
# Better accuracy:0.9111111111111111
# Better accuracy:0.9777777777777777
# Better accuracy:1.0
# initial_accuracy: 0.0
# initial_accuracy: 0.022222222222222223
# Better accuracy:0.044444444444444446
# Better accuracy:0.08888888888888889
# Better accuracy:0.1111111111111111
# Better accuracy:0.13333333333333333
# Better accuracy:0.15555555555555556
# Better accuracy:0.7777777777777778
# Better accuracy:0.8444444444444444
# Better accuracy:0.9111111111111111
# Better accuracy:0.9777777777777777
# Better accuracy:1.0
# initial_accuracy: 0.1111111111111111
# Better accuracy:0.13333333333333333
# Better accuracy:0.3111111111111111
# Better accuracy:0.35555555555555557
# Better accuracy:0.7555555555555555
# Better accuracy:0.8222222222222222
# Better accuracy:0.8888888888888888
# Better accuracy:0.9555555555555556
# Better accuracy:0.9777777777777777
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.10344827586206896
# Better accuracy:0.13793103448275862
# Better accuracy:0.1724137931034483
# Better accuracy:0.20689655172413793
# Better accuracy:0.2413793103448276
# Better accuracy:0.27586206896551724
# Better accuracy:0.3448275862068966
# Better accuracy:0.4482758620689655
# Better accuracy:0.4827586206896552
# Better accuracy:0.5172413793103449
# Better accuracy:0.5517241379310345
# Better accuracy:0.5862068965517241
# Better accuracy:0.6206896551724138
# Better accuracy:0.6551724137931034
# Better accuracy:0.6896551724137931
# Better accuracy:0.8275862068965517
# Better accuracy:0.896551724137931
# Better accuracy:0.9310344827586207
# Better accuracy:0.9655172413793104
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.37777777777777777
# Better accuracy:0.4
# Better accuracy:0.7777777777777778
# Better accuracy:0.8444444444444444
# Better accuracy:0.9111111111111111
# Better accuracy:0.9777777777777777
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.10344827586206896
# Better accuracy:0.13793103448275862
# Better accuracy:0.1724137931034483
# Better accuracy:0.20689655172413793
# Better accuracy:0.2413793103448276
# Better accuracy:0.27586206896551724
# Better accuracy:0.3793103448275862
# Better accuracy:0.5517241379310345
# Better accuracy:0.5862068965517241
# Better accuracy:0.6206896551724138
# Better accuracy:0.6551724137931034
# Better accuracy:0.6896551724137931
# Better accuracy:0.8620689655172413
# Better accuracy:0.9310344827586207
# Better accuracy:0.9655172413793104
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.06896551724137931
# Better accuracy:0.10344827586206896
# Better accuracy:0.1724137931034483
# Better accuracy:0.20689655172413793
# Better accuracy:0.2413793103448276
# Better accuracy:0.27586206896551724
# Better accuracy:0.3793103448275862
# Better accuracy:0.5517241379310345
# Better accuracy:0.5862068965517241
# Better accuracy:0.6206896551724138
# Better accuracy:0.6551724137931034
# Better accuracy:0.6896551724137931
# Better accuracy:0.896551724137931
# Better accuracy:0.9310344827586207
# Better accuracy:0.9655172413793104
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.17777777777777778
# Better accuracy:0.2
# Better accuracy:0.7777777777777778
# Better accuracy:0.8444444444444444
# Better accuracy:0.9111111111111111
# Better accuracy:0.9777777777777777
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.6888888888888889
# Better accuracy:0.7333333333333333
# Better accuracy:0.7555555555555555
# Better accuracy:0.7777777777777778
# Better accuracy:0.8444444444444444
# Better accuracy:0.9111111111111111
# Better accuracy:0.9777777777777777
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.034482758620689655
# Better accuracy:0.06896551724137931
# Better accuracy:0.1724137931034483
# Better accuracy:0.20689655172413793
# Better accuracy:0.2413793103448276
# Better accuracy:0.27586206896551724
# Better accuracy:0.3793103448275862
# ...
# Better accuracy:0.2857142857142857
# Better accuracy:0.3142857142857143
# Better accuracy:0.34285714285714286
# Better accuracy:0.42857142857142855
# Better accuracy:0.45714285714285713
# Better accuracy:0.4857142857142857
# Better accuracy:0.5142857142857142
# Better accuracy:0.5428571428571428
# Better accuracy:0.5714285714285714
# Better accuracy:0.6285714285714286
# initial_accuracy: 0.02564102564102564
# initial_accuracy: 0.07692307692307693
# Better accuracy:0.6153846153846154
# Better accuracy:0.6410256410256411
# Better accuracy:0.717948717948718
# Better accuracy:0.7692307692307693
# Better accuracy:0.7948717948717948
# Better accuracy:0.8717948717948718
# Better accuracy:0.8974358974358975
# Better accuracy:0.9230769230769231
# Better accuracy:0.9487179487179487
# Better accuracy:0.9743589743589743
# initial_accuracy: 0.02857142857142857
# Better accuracy:0.05714285714285714
# Better accuracy:0.08571428571428572
# Better accuracy:0.11428571428571428
# Better accuracy:0.2
# Better accuracy:0.22857142857142856
# Better accuracy:0.2571428571428571
# Better accuracy:0.2857142857142857
# Better accuracy:0.3142857142857143
# Better accuracy:0.34285714285714286
# Better accuracy:0.42857142857142855
# Better accuracy:0.45714285714285713
# Better accuracy:0.4857142857142857
# Better accuracy:0.5142857142857142
# Better accuracy:0.5428571428571428
# Better accuracy:0.5714285714285714
# Better accuracy:0.6285714285714286
# initial_accuracy: 0.0
# Better accuracy:0.11428571428571428
# Better accuracy:0.14285714285714285
# Better accuracy:0.2
# Better accuracy:0.22857142857142856
# Better accuracy:0.2571428571428571
# Better accuracy:0.2857142857142857
# Better accuracy:0.3142857142857143
# Better accuracy:0.34285714285714286
# Better accuracy:0.42857142857142855
# Better accuracy:0.45714285714285713
# Better accuracy:0.4857142857142857
# Better accuracy:0.5142857142857142
# Better accuracy:0.5428571428571428
# Better accuracy:0.5714285714285714
# Better accuracy:0.6285714285714286
# initial_accuracy: 0.0
# Better accuracy:0.11428571428571428
# Better accuracy:0.14285714285714285
# Better accuracy:0.2
# Better accuracy:0.22857142857142856
# Better accuracy:0.2571428571428571
# Better accuracy:0.2857142857142857
# Better accuracy:0.3142857142857143
# Better accuracy:0.34285714285714286
# Better accuracy:0.42857142857142855
# Better accuracy:0.45714285714285713
# Better accuracy:0.4857142857142857
# Better accuracy:0.5142857142857142
# Better accuracy:0.5428571428571428
# Better accuracy:0.5714285714285714
# Better accuracy:0.6285714285714286
# Better accuracy:0.6571428571428571
# Better accuracy:0.6857142857142857
# initial_accuracy: 0.0
# Better accuracy:0.2564102564102564
# Better accuracy:0.28205128205128205
# Better accuracy:0.7948717948717948
# Better accuracy:0.8205128205128205
# Better accuracy:0.8974358974358975
# Better accuracy:0.9230769230769231
# Better accuracy:0.9487179487179487
# Better accuracy:0.9743589743589743
# initial_accuracy: 0.0
# Better accuracy:0.02564102564102564
# Better accuracy:0.7948717948717948
# Better accuracy:0.8205128205128205
# Better accuracy:0.8974358974358975
# Better accuracy:0.9230769230769231
# Better accuracy:0.9487179487179487
# Better accuracy:0.9743589743589743
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.7948717948717948
# Better accuracy:0.8205128205128205
# Better accuracy:0.8974358974358975
# Better accuracy:0.9230769230769231
# Better accuracy:0.9487179487179487
# Better accuracy:0.9743589743589743
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.7948717948717948
# Better accuracy:0.8205128205128205
# Better accuracy:0.8974358974358975
# Better accuracy:0.9230769230769231
# Better accuracy:0.9487179487179487
# Better accuracy:0.9743589743589743
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.6666666666666666
# Better accuracy:0.6923076923076923
# Better accuracy:0.7692307692307693
# Better accuracy:0.7948717948717948
# Better accuracy:0.8205128205128205
# Better accuracy:0.8974358974358975
# Better accuracy:0.9230769230769231
# Better accuracy:0.9487179487179487
# Better accuracy:0.9743589743589743
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.08571428571428572
# Better accuracy:0.11428571428571428
# Better accuracy:0.22857142857142856
# Better accuracy:0.2571428571428571
# Better accuracy:0.2857142857142857
# Better accuracy:0.3142857142857143
# Better accuracy:0.34285714285714286
# Better accuracy:0.37142857142857144
# Better accuracy:0.4857142857142857
# Better accuracy:0.5142857142857142
# Better accuracy:0.5428571428571428
# Better accuracy:0.5714285714285714
# Better accuracy:0.6285714285714286
# Better accuracy:0.6571428571428571
# Better accuracy:0.6857142857142857
# initial_accuracy: 0.0
# Better accuracy:0.11428571428571428
# Better accuracy:0.22857142857142856
# Better accuracy:0.2571428571428571
# Better accuracy:0.34285714285714286
# Better accuracy:0.37142857142857144
# Better accuracy:0.4
# Better accuracy:0.42857142857142855
# Better accuracy:0.4857142857142857
# Better accuracy:0.7142857142857143
# Better accuracy:0.7714285714285715
# Better accuracy:0.8
# Better accuracy:0.8571428571428571
# Better accuracy:0.9428571428571428
# Better accuracy:0.9714285714285714
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.02857142857142857
# Better accuracy:0.22857142857142856
# Better accuracy:0.2857142857142857
# Better accuracy:0.37142857142857144
# Better accuracy:0.42857142857142855
# Better accuracy:0.45714285714285713
# Better accuracy:0.5428571428571428
# Better accuracy:0.8
# Better accuracy:0.8571428571428571
# Better accuracy:0.9428571428571428
# Better accuracy:0.9714285714285714
# Better accuracy:1.0
# initial_accuracy: 0.02564102564102564
# Better accuracy:0.46153846153846156
# Better accuracy:0.48717948717948717
# Better accuracy:0.9230769230769231
# Better accuracy:0.9487179487179487
# Better accuracy:0.9743589743589743
# Better accuracy:1.0
# initial_accuracy: 0.08571428571428572
# Better accuracy:0.3142857142857143
# Better accuracy:0.34285714285714286
# Better accuracy:0.4
# Better accuracy:0.45714285714285713
# Better accuracy:0.6857142857142857
# Better accuracy:0.7428571428571429
# Better accuracy:0.7714285714285715
# Better accuracy:0.8285714285714286
# Better accuracy:0.9142857142857143
# Better accuracy:0.9428571428571428
# Better accuracy:0.9714285714285714
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.07692307692307693
# Better accuracy:0.46153846153846156
# Better accuracy:0.48717948717948717
# Better accuracy:0.9230769230769231
# Better accuracy:0.9487179487179487
# Better accuracy:0.9743589743589743
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.3142857142857143
# Better accuracy:0.37142857142857144
# Better accuracy:0.45714285714285713
# Better accuracy:0.5428571428571428
# Better accuracy:0.8
# Better accuracy:0.8571428571428571
# Better accuracy:0.9428571428571428
# Better accuracy:0.9714285714285714
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.02857142857142857
# Better accuracy:0.3142857142857143
# Better accuracy:0.37142857142857144
# Better accuracy:0.45714285714285713
# Better accuracy:0.5428571428571428
# Better accuracy:0.8285714285714286
# Better accuracy:0.8857142857142857
# Better accuracy:0.9714285714285714
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.3142857142857143
# Better accuracy:0.37142857142857144
# Better accuracy:0.45714285714285713
# Better accuracy:0.5428571428571428
# Better accuracy:0.8285714285714286
# Better accuracy:0.8857142857142857
# Better accuracy:0.9714285714285714
# initial_accuracy: 0.0
# Better accuracy:0.3142857142857143
# Better accuracy:0.37142857142857144
# Better accuracy:0.45714285714285713
# Better accuracy:0.5428571428571428
# Better accuracy:0.8571428571428571
# Better accuracy:0.9142857142857143
# initial_accuracy: 0.0
# Better accuracy:0.02857142857142857
# Better accuracy:0.3142857142857143
# Better accuracy:0.37142857142857144
# Better accuracy:0.45714285714285713
# Better accuracy:0.5428571428571428
# Better accuracy:0.9142857142857143
# initial_accuracy: 0.02857142857142857
# Better accuracy:0.05714285714285714
# Better accuracy:0.34285714285714286
# Better accuracy:0.42857142857142855
# Better accuracy:0.4857142857142857
# Better accuracy:0.6285714285714286
# initial_accuracy: 0.08571428571428572
# Better accuracy:0.2571428571428571
# Better accuracy:0.42857142857142855
# Better accuracy:0.6857142857142857
# initial_accuracy: 0.14285714285714285
# Better accuracy:0.3142857142857143
# Better accuracy:0.5714285714285714
# initial_accuracy: 0.42857142857142855
# Better accuracy:0.9714285714285714
# initial_accuracy: 0.0
# Better accuracy:0.02564102564102564
# after pruning: 211
# Number of Rules after pruning 30
# Accuracy of Test Data With Rules 0.7934782608695652
# f1_score of Test Data With Rules 0.7466666666666667
# recall_score of Test Data With Rules 0.7567567567567568
# before pruning: 363
# initial_accuracy: 0.5925925925925926
# Better accuracy:0.6111111111111112
# Better accuracy:0.8333333333333334
# Better accuracy:0.8518518518518519
# Better accuracy:0.8703703703703703
# Better accuracy:0.8888888888888888
# Better accuracy:0.9074074074074074
# Better accuracy:0.9259259259259259
# Better accuracy:0.9444444444444444
# Better accuracy:0.9629629629629629
# Better accuracy:0.9814814814814815
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.05
# Better accuracy:0.15
# Better accuracy:0.2
# Better accuracy:0.3
# Better accuracy:0.35
# Better accuracy:0.4
# Better accuracy:0.5
# Better accuracy:0.55
# Better accuracy:0.6
# Better accuracy:0.65
# Better accuracy:0.7
# Better accuracy:0.75
# Better accuracy:0.8
# Better accuracy:0.85
# Better accuracy:0.9
# Better accuracy:1.0
# initial_accuracy: 0.018518518518518517
# Better accuracy:0.14814814814814814
# Better accuracy:0.46296296296296297
# Better accuracy:0.48148148148148145
# Better accuracy:0.5
# Better accuracy:0.5185185185185185
# Better accuracy:0.8333333333333334
# Better accuracy:0.8518518518518519
# Better accuracy:0.8703703703703703
# Better accuracy:0.8888888888888888
# Better accuracy:0.9074074074074074
# Better accuracy:0.9259259259259259
# Better accuracy:0.9444444444444444
# Better accuracy:0.9629629629629629
# Better accuracy:0.9814814814814815
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.15
# Better accuracy:0.2
# Better accuracy:0.25
# Better accuracy:0.3
# Better accuracy:0.35
# Better accuracy:0.4
# Better accuracy:0.45
# Better accuracy:0.55
# Better accuracy:0.6
# Better accuracy:0.65
# Better accuracy:0.7
# Better accuracy:0.75
# Better accuracy:0.8
# Better accuracy:0.85
# Better accuracy:0.95
# Better accuracy:1.0
# initial_accuracy: 0.2222222222222222
# Better accuracy:0.24074074074074073
# Better accuracy:0.25925925925925924
# Better accuracy:0.3148148148148148
# Better accuracy:0.3333333333333333
# Better accuracy:0.35185185185185186
# Better accuracy:0.48148148148148145
# Better accuracy:0.5
# Better accuracy:0.5185185185185185
# Better accuracy:0.8333333333333334
# Better accuracy:0.8518518518518519
# Better accuracy:0.8703703703703703
# Better accuracy:0.8888888888888888
# Better accuracy:0.9074074074074074
# Better accuracy:0.9259259259259259
# Better accuracy:0.9444444444444444
# Better accuracy:0.9629629629629629
# Better accuracy:0.9814814814814815
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.05
# Better accuracy:0.3
# Better accuracy:0.35
# Better accuracy:0.4
# Better accuracy:0.5
# Better accuracy:0.55
# Better accuracy:0.65
# Better accuracy:0.7
# Better accuracy:0.75
# Better accuracy:0.8
# Better accuracy:0.85
# Better accuracy:0.95
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.4074074074074074
# Better accuracy:0.42592592592592593
# Better accuracy:0.4444444444444444
# Better accuracy:0.8333333333333334
# Better accuracy:0.8518518518518519
# Better accuracy:0.8703703703703703
# Better accuracy:0.8888888888888888
# Better accuracy:0.9074074074074074
# Better accuracy:0.9259259259259259
# Better accuracy:0.9444444444444444
# Better accuracy:0.9629629629629629
# Better accuracy:0.9814814814814815
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.7592592592592593
# Better accuracy:0.7777777777777778
# Better accuracy:0.7962962962962963
# Better accuracy:0.8333333333333334
# Better accuracy:0.8518518518518519
# Better accuracy:0.8703703703703703
# Better accuracy:0.8888888888888888
# Better accuracy:0.9074074074074074
# Better accuracy:0.9259259259259259
# Better accuracy:0.9444444444444444
# Better accuracy:0.9629629629629629
# Better accuracy:0.9814814814814815
# Better accuracy:1.0
# initial_accuracy: 0.0
# initial_accuracy: 0.018518518518518517
# Better accuracy:0.8518518518518519
# Better accuracy:0.8703703703703703
# Better accuracy:0.8888888888888888
# Better accuracy:0.9074074074074074
# Better accuracy:0.9259259259259259
# Better accuracy:0.9444444444444444
# Better accuracy:0.9629629629629629
# Better accuracy:0.9814814814814815
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.8518518518518519
# Better accuracy:0.8703703703703703
# Better accuracy:0.8888888888888888
# Better accuracy:0.9074074074074074
# Better accuracy:0.9259259259259259
# Better accuracy:0.9444444444444444
# Better accuracy:0.9629629629629629
# Better accuracy:0.9814814814814815
# Better accuracy:1.0
# initial_accuracy: 0.037037037037037035
# Better accuracy:0.05555555555555555
# Better accuracy:0.8888888888888888
# Better accuracy:0.9074074074074074
# Better accuracy:0.9259259259259259
# Better accuracy:0.9444444444444444
# Better accuracy:0.9629629629629629
# Better accuracy:0.9814814814814815
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.3
# Better accuracy:0.35
# Better accuracy:0.4
# Better accuracy:0.55
# Better accuracy:0.6
# Better accuracy:0.65
# Better accuracy:0.7
# Better accuracy:0.75
# Better accuracy:1.0
# initial_accuracy: 0.05
# Better accuracy:0.1
# Better accuracy:0.3
# Better accuracy:0.35
# Better accuracy:0.4
# Better accuracy:0.45
# Better accuracy:0.6
# Better accuracy:0.65
# Better accuracy:0.7
# Better accuracy:0.8
# Better accuracy:0.9
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.12962962962962962
# Better accuracy:0.14814814814814814
# Better accuracy:0.8888888888888888
# Better accuracy:0.9074074074074074
# Better accuracy:0.9259259259259259
# Better accuracy:0.9444444444444444
# Better accuracy:0.9629629629629629
# Better accuracy:0.9814814814814815
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.35
# Better accuracy:0.4
# Better accuracy:0.45
# Better accuracy:0.6
# Better accuracy:0.65
# Better accuracy:0.7
# Better accuracy:0.8
# Better accuracy:0.9
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.35
# Better accuracy:0.4
# Better accuracy:0.45
# Better accuracy:0.6
# Better accuracy:0.65
# Better accuracy:0.7
# Better accuracy:0.8
# Better accuracy:0.9
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.35
# Better accuracy:0.4
# Better accuracy:0.45
# Better accuracy:0.6
# Better accuracy:0.65
# Better accuracy:0.7
# Better accuracy:0.8
# Better accuracy:0.9
# Better accuracy:1.0
# initial_accuracy: 0.0
# Better accuracy:0.35
# Better accuracy:0.4
# Better accuracy:0.45
# Better accuracy:0.6
# Better accuracy:0.65
# Better accuracy:0.7
# Better accuracy:0.8
# Better accuracy:0.9
# initial_accuracy: 0.0
# Better accuracy:0.05
# Better accuracy:0.35
# Better accuracy:0.4
# Better accuracy:0.5
# Better accuracy:0.65
# Better accuracy:0.7
# Better accuracy:0.75
# Better accuracy:0.85
# Better accuracy:0.9
# initial_accuracy: 0.05
# Better accuracy:0.1
# Better accuracy:0.4
# Better accuracy:0.45
# Better accuracy:0.5
# Better accuracy:0.65
# Better accuracy:0.75
# Better accuracy:0.8
# Better accuracy:0.9
# initial_accuracy: 0.0
# Better accuracy:0.05
# Better accuracy:0.4
# Better accuracy:0.45
# Better accuracy:0.5
# Better accuracy:0.6
# Better accuracy:0.9
# initial_accuracy: 0.05
# Better accuracy:0.1
# Better accuracy:0.45
# Better accuracy:0.5
# Better accuracy:0.6
# Better accuracy:0.7
# initial_accuracy: 0.05
# Better accuracy:0.25
# Better accuracy:0.5
# Better accuracy:0.75
# initial_accuracy: 0.2
# Better accuracy:0.25
# Better accuracy:0.7
# initial_accuracy: 0.3
# Better accuracy:0.9
# Better accuracy:0.95
# initial_accuracy: 0.0
# Better accuracy:0.018518518518518517
# Better accuracy:0.037037037037037035
# Better accuracy:0.9074074074074074
# initial_accuracy: 0.0
# Better accuracy:0.09259259259259259
# after pruning: 162
# Number of Rules after pruning 28
# Mean Accuracy So Far on Test: 0.7217391304347827
# The Mean Accuracy of Classifier 0.8489130434782609
# The Mean Variance of Classifier 0.00201913988657845
# Mean f1_score So Far on Test: 0.8059320796042029
# Mean recall_score So Far on Test: 0.8215734487416301

# %%
# %run "Python-DM-Classification-04-C4.5"

# %%
# df = pd.read_csv('Python-DM-Classification-04-C4.5.csv', sep = ';')
df = spam_data_sampled.reset_index(drop=True)
print(df.shape)
X = df.iloc[:, 0:-1]
y = df.iloc[:, -1]
print(y)
dt_model = dt_c45(Xdata = X, ydata = y, cat_missing = "none", num_missing = "none", pre_pruning = "impur", chi_lim = 0.1, min_lim = 5)

# Calling Prediction
test =  df.iloc[0:2, 0:-1]
prediction_dt_c45(dt_model, test)
# Out:
# (460, 58)
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
# 5      1
# 6      1
# 7      1
# 8      0
# 9      0
# 10     1
# 11     0
# 12     1
# 13     0
# 14     0
# 15     0
# 16     0
# 17     0
# 18     0
# 19     1
# 20     0
# 21     0
# 22     0
# 23     1
# 24     1
# 25     1
# 26     1
# 27     1
# 28     0
# 29     0
#       ..
# 430    0
# 431    0
# 432    0
# 433    0
# 434    1
# 435    0
# 436    1
# 437    0
# 438    0
# 439    1
# 440    0
# 441    1
# 442    0
# 443    1
# 444    1
# 445    0
# 446    0
# 447    0
# 448    1
# 449    1
# 450    1
# 451    0
# 452    0
# 453    1
# 454    1
# 455    0
# 456    0
# 457    0
# 458    0
# 459    1
# Name: Class, Length: 460, dtype: int64
# 460
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# 460
# ['one' 'zero']
# iteration:  1
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# 368
# ['one' 'zero']
# iteration:  2
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# 92
# ['one' 'zero']
# iteration:  3
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# 349
# ['one' 'zero']
# iteration:  4
# 19
# ['one']
# iteration:  5
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# 90
# ['one' 'zero']
# iteration:  6
# 2
# ['zero']
# iteration:  7
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# 337
# ['one' 'zero']
# iteration:  8
# 12
# ['one']
# iteration:  9
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# 87
# ['one' 'zero']
# iteration:  10
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# iteration:  11
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# 329
# ['one' 'zero']
# iteration:  12
# 8
# ['one']
# iteration:  13
# 84
# ['one']
# iteration:  14
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# 3
# ['one' 'zero']
# iteration:  15
# 1
# ['zero']
# iteration:  16
# 2
# ['one']
# iteration:  17
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# 322
# ['one' 'zero']
# iteration:  18
# 7
# ['one']
# iteration:  19
# 1
# ['zero']
# iteration:  20
# 2
# ['one']
# iteration:  21
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# 319
# ['one' 'zero']
# iteration:  22
# 3
# ['one']
# iteration:  23
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# 317
# ['one' 'zero']
# iteration:  24
# 2
# ['one']
# iteration:  25
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# 305
# ['one' 'zero']
# iteration:  26
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# 12
# ['one' 'zero']
# iteration:  27
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
# 303
# ['one' 'zero']
